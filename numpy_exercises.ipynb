# %% [markdown]
# ARRAYS são parecidas com listas, mas com maior velocidade e memória.

# %%
import numpy as np
url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'
data = np.loadtxt(url, delimiter=',', usecols=np.arange(1, 88, 1))
#carregará os valores de 1 a 88 da URL e os armazenará em data.
print(data)
# Out:
# [[  1.2013   2.2013   3.2013   4.2013   5.2013   6.2013   7.2013   8.2013
#     9.2013  10.2013  11.2013  12.2013   1.2014   2.2014   3.2014   4.2014
#     5.2014   6.2014   7.2014   8.2014   9.2014  10.2014  11.2014  12.2014
#     1.2015   2.2015   3.2015   4.2015   5.2015   6.2015   7.2015   8.2015
#     9.2015  10.2015  11.2015  12.2015   1.2016   2.2016   3.2016   4.2016
#     5.2016   6.2016   7.2016   8.2016   9.2016  10.2016  11.2016  12.2016
#     1.2017   2.2017   3.2017   4.2017   5.2017   6.2017   7.2017   8.2017
#     9.2017  10.2017  11.2017  12.2017   1.2018   2.2018   3.2018   4.2018
#     5.2018   6.2018   7.2018   8.2018   9.2018  10.2018  11.2018  12.2018
#     1.2019   2.2019   3.2019   4.2019   5.2019   6.2019   7.2019   8.2019
#     9.2019  10.2019  11.2019  12.2019   1.202    2.202    3.202 ]
#  [ 79.72    81.08    79.68    79.8     80.63    80.8     80.28    78.99
#    76.77    76.09    76.36    77.16    77.5     79.03    80.28    80.05
# ...

# %%
print(data.ndim) #dimension
print(data.size) #hom many elements
print(data.shape) #formats lines and rows
data_transposed = data.T#transposed matrix
print(data_transposed)
# Out:
# 2
# 522
# (6, 87)
# [[  1.2013  79.72    42.67    62.55    48.26    71.25  ]
#  [  2.2013  81.08    44.37    62.73    51.01    71.35  ]
#  [  3.2013  79.68    44.73    63.43    50.91    70.9   ]
#  [  4.2013  79.8     46.75    63.83    53.94    71.92  ]
#  [  5.2013  80.63        nan  66.06    61.27    72.91  ]
#  [  6.2013  80.8     51.59    69.22    65.44    74.39  ]
#  [  7.2013  80.28    57.8     72.07    56.51    73.1   ]
#  [  8.2013  78.99    62.14    69.31    53.      70.24  ]
#  [  9.2013  76.77    56.76    65.18    43.87    69.12  ]
#  [ 10.2013  76.09    50.85    62.13    42.12    68.98  ]
#  [ 11.2013  76.36    46.43    64.17    43.98    68.58  ]
#  [ 12.2013  77.16    46.73    65.5     44.66    69.5   ]
#  [  1.2014  77.5     45.85    66.85    47.73    70.14  ]
#  [  2.2014  79.03    49.25    68.38    52.31    70.58  ]
#  [  3.2014  80.28    48.14    68.77    56.8     70.78  ]
#  [  4.2014  80.05    49.18    69.32    51.15    72.78  ]
# ...

# %%
import numpy as np
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'
data = np.loadtxt(url, delimiter=',',usecols=np.arange(1,6,1),skiprows=1)
data
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %% [markdown]
# #### Given the example of a periodic event above, create an array, using the np.arange() function, that lists all the years where the World Cup took place or is expected to take place, considering the closed interval from 2000 to 2102.

# %%
import numpy as np

ano_inicial = 2002
ano_final = 2102
np.arange(ano_inicial, ano_final + 1, 4)
# Out:
# array([2002, 2006, 2010, 2014, 2018, 2022, 2026, 2030, 2034, 2038, 2042,
#        2046, 2050, 2054, 2058, 2062, 2066, 2070, 2074, 2078, 2082, 2086,
#        2090, 2094, 2098, 2102])

# %%
import numpy as np

# create a list
list = [1,2,3,4,5]

# transform the list in an array Numpy
array = np.array(list)

print("Lista: ",list)
print("Array: ",array)
# Out:
# Lista:  [1, 2, 3, 4, 5]
# Array:  [1 2 3 4 5]

# %% [markdown]
# processing efficiency
# Mathematical operations on Numpy arrays are much faster than on regular lists, as NumPy has been optimized to work with homogeneous datasets and frees up computer memory quickly.
#
# ease of use
# Mathematical operations in Numpy arrays are expressed much more clearly and concisely than in regular lists, making the code easier to read and maintain.
#
# Integration with other libraries
# Numpy is one of the most used libraries in data science and machine learning, and many other libraries such as Pandas and Matplotlib are designed to work directly with Numpy arrays.

# %% [markdown]
# Performance benchmark: lists vs arrays
#
# Focusing on efficiency, we can compare the time taken to perform a calculation using lists and arrays.

# %%
import numpy as np

# cria uma lista
lista = [1, 2, 3, 4, 5]

# transforma a lista em um array Numpy
array = np.array(lista)

print("Lista: ", lista)
print("Array: ", array)
# Out:
# Lista:  [1, 2, 3, 4, 5]
# Array:  [1 2 3 4 5]

# %%
dates = data_transposed[:,0] #all lines and zero colluns [:,0]
prices = data_transposed[:,1:6] #alll lines columns one to five

prices
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,  66.06,  61.27,  72.91],
#        [ 80.8 ,  51.59,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(dates,prices[:,0])# x and y axes

# %%
dates
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
dates = np.arange(1,88,1)
plt.plot(dates,prices[:,0])# x and y axes

# %%
Moscow = prices[:,0]
Kalininggrad = prices[:,1]
Petersburg = prices[:,2]
Krasnodar = prices[:,3]
Ekaterinburg = prices[:,4]
print(Moscow)
print(Moscow.shape)
# Out:
# [ 79.72  81.08  79.68  79.8   80.63  80.8   80.28  78.99  76.77  76.09
#   76.36  77.16  77.5   79.03  80.28  80.05  78.11  76.9   77.68  76.05
#   75.53  73.39  78.36  89.16 105.43 104.82 101.15  98.63  99.96  97.29
#   98.64 104.26 102.63  98.64  97.17  98.09 103.07 110.26 110.84 112.28
#  111.1  110.06 113.7  112.88 102.08  95.54  91.33  89.99  91.44  93.51
#   93.6   93.78  98.91 121.76 129.6  127.9  114.55 101.88  99.09 103.35
#  106.58 108.   114.95 121.17 122.48 127.58 131.89 129.36 104.26  93.45
#   92.93  96.15  99.1  103.   103.31 103.01 107.37 116.91 125.29 123.94
#  113.03 102.19  97.83 101.07 103.44 108.23 110.28]
# (87,)

# %%
#Splitting the array by years
Moscow_y1 = Moscow[0:12]#12 firsts values
Moscow_y2 = Moscow[13:25]
Moscow_y3 = Moscow[25:37]
Moscow_y4 = Moscow[37:49]

# %%
plt.plot(np.arange(1,13,1),Moscow_y1)
plt.plot(np.arange(1,13,1),Moscow_y2)
plt.plot(np.arange(1,13,1),Moscow_y3)
plt.plot(np.arange(1,13,1),Moscow_y4)
plt.legend(['y1','y2','y3','y4'])

# %%
np.array_equal(Moscow_y3,Moscow_y4)#is it equal ?
# Out:
# False

# %%
np.allclose(Moscow_y3,Moscow_y4,0.01)
# Out:
# False

# %%
plt.plot(dates,Kalininggrad)

# %%
Kalininggrad #theis is a nan value
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
np.isnan(Kalininggrad)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
sum(np.isnan(Kalininggrad))
# Out:
# 1

# %%
Kalininggrad[4]=np.mean([Kalininggrad[3],Kalininggrad[5]]) #using mean to get rid of null data

# %%
plt.plot(dates,Kalininggrad)

# %%
#comparing the average price of Russian cities

print(np.mean(Moscow))
print(np.mean(Kalininggrad))
# Out:
# 98.79781609195402
# 74.5506896551724

# %%
plt.plot(dates,Moscow)

# %%
#ajuastar uma reta aos dados para entneder a taxa de crescimento
# y = ax + b
x = dates
y = 2*x +80
plt.plot(dates, Moscow)
plt.plot(x,y)

# %%
np.power(Moscow-y,2)
# Out:
# array([5.19840000e+00, 8.52640000e+00, 3.99424000e+01, 6.72400000e+01,
#        8.77969000e+01, 1.25440000e+02, 1.88238400e+02, 2.89340100e+02,
#        4.50712900e+02, 5.71688100e+02, 6.57409600e+02, 7.20385600e+02,
#        8.12250000e+02, 8.39260900e+02, 8.83278400e+02, 1.02080250e+03,
#        1.28809210e+03, 1.52881000e+03, 1.62570240e+03, 1.93160250e+03,
#        2.15946090e+03, 2.56137210e+03, 2.26956960e+03, 1.50854560e+03,
#        6.03684900e+02, 7.38752400e+02, 1.07912250e+03, 1.39651690e+03,
#        1.44704160e+03, 1.82414410e+03, 1.88008960e+03, 1.57926760e+03,
#        1.88095690e+03, 2.43640960e+03, 2.79100890e+03, 2.90628810e+03,
#        2.59386490e+03, 2.09214760e+03, 2.22406560e+03, 2.27719840e+03,
#        2.59081000e+03, 2.90952360e+03, 2.73529000e+03, 3.03821440e+03,
#        4.61312640e+03, 5.84613160e+03, 6.83432890e+03, 7.39772010e+03,
#        7.49263360e+03, 7.48052010e+03, 7.81456000e+03, 8.13964840e+03,
# ...

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
y = 0.52*x+80

# %%
plt.plot(dates,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %%
Y = Moscow
X = dates
n = np.size(Moscow)
(n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)
b = np.mean(Y) - a*np.mean(X)
y = a*X+b
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
plt.plot(dates,Moscow)
plt.plot(x,y)
plt.plot(41.5,41.5*a+b,'*r')
plt.plot(100,100*a+b,'*r')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerar uma sequência de valores de x de -1 a 1
x = np.arange(-1, 1, 0.0001)

# Implementação da fórmula
y1 = np.sqrt(1 - x**2)
y2 = -np.sqrt(1 - x**2)

# Plotar o gráfico com as duas partes do círculo
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'r' )

# Adicionar o título do gráfico e os rótulos dos eixos x e y
plt.title("Círculo")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Basic:

# %% [markdown]
# ### Create a NumPy array of 10 elements.

# %% [markdown]
# ### Create a NumPy array of 5 rows and 2 columns.

# %% [markdown]
# ### Create a NumPy array of random numbers.

# %% [markdown]
# ### Create a NumPy array of integers.

# %% [markdown]
# ### Create a NumPy array of floating-point numbers.

# %% [markdown]
# ### Create a NumPy array of complex numbers.

# %% [markdown]
# ### Create a one-dimensional NumPy array.

# %% [markdown]
# ### Create a two-dimensional NumPy array.

# %% [markdown]
# ### Create a three-dimensional NumPy array.

# %% [markdown]
# ### Create a four-dimensional NumPy array.

# %% [markdown]
# ### Create a five-dimensional NumPy array.

# %% [markdown]
# # Intermediary:

# %% [markdown]
# ### Add two NumPy arrays.

# %% [markdown]
# ### Subtract two NumPy arrays.

# %% [markdown]
# ### Multiply two NumPy arrays.

# %% [markdown]
# ### Divide two NumPy arrays.

# %% [markdown]
# ### Raise two NumPy arrays to a power.

# %% [markdown]
# ### Take the square root of two NumPy arrays.

# %% [markdown]
# ### Take the logarithm of two NumPy arrays.

# %% [markdown]
# ### Take the exponential of two NumPy arrays.

# %% [markdown]
# ### Take the sine of two NumPy arrays.

# %% [markdown]
# ### Take the cosine of two NumPy arrays.

# %% [markdown]
# ### Take the tangent of two NumPy arrays.

# %% [markdown]
# # Advanced:

# %% [markdown]
# ### Calculate the mean of a NumPy array.

# %% [markdown]
# ### Calculate the median of a NumPy array.

# %% [markdown]
# ### Calculate the standard deviation of a NumPy array.

# %% [markdown]
# ### Calculate the variance of a NumPy array.

# %% [markdown]
# ### Calculate the mode of a NumPy array.

# %% [markdown]
# ### Calculate the minimum of a NumPy array.

# %% [markdown]
# ### Calculate the maximum of a NumPy array.

# %% [markdown]
# ### Calculate the sum of a NumPy array.

# %% [markdown]
# ### Calculate the product of a NumPy array.

# %% [markdown]
# ### Calculate the count of a NumPy array.

# %% [markdown]
# ### Calculate the difference of a NumPy array.
